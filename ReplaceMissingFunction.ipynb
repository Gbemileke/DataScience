# %%
def ReplaceMissing(df,col,value):
    df[col].replace(np.nan, value, inplace = True)

# %%
import numpy as np 
#load data from CSV
import pandas as pd
df=pd.read_csv('train_values.csv')
print('Data loaded')
# Out:
# Data loaded

# %%
df.head()
# Out:
#    row_id country_code  year  agricultural_land_area  \
# 0       0      889f053  2002           235077.658128
# 1       1      9e614ab  2012            23000.640738
# 2       2      100c476  2000               90.954867
# 3       3      4609682  2013           100843.661212
# 4       4      be2a7f5  2008              224.289357
#
#    percentage_of_arable_land_equipped_for_irrigation  cereal_yield  \
# 0                                          38.558520    935.754365
# 1                                          21.282631   4031.452161
# 2                                           4.317080   1581.935278
# 3                                          16.636618   1127.626364
# 4                                                NaN   1418.987212
#
#    droughts_floods_extreme_temps    forest_area  total_land_area  \
# 0                            0.0    5397.737544    537408.312513
# 1                            0.0  178336.529912    232013.631676
# ...

# %%
df['droughts_floods_extreme_temps']
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.000000
# 7       0.000000
# 8       0.000000
# 9       0.000000
# 10      0.000000
# 11      1.257778
# 12      0.000000
# 13      0.000000
# 14      0.000000
# 15      0.000000
# 16      0.000000
# 17      0.000000
# 18      0.000000
# 19      0.000000
# 20      0.000000
# 21      0.000000
# 22      0.000000
# 23      0.000000
# 24      0.000000
# 25      0.000000
# 26      0.000000
# 27      0.000000
# 28      0.000000
# 29      0.000000
#           ...
# 1371    0.000000
# 1372    0.000000
# 1373    0.166381
# 1374    0.000000
# 1375    0.000000
# 1376    0.000000
# 1377    0.000000
# 1378    0.000000
# 1379    0.000000
# 1380    0.000000
# 1381    0.000000
# 1382    0.000000
# 1383    0.000000
# 1384    0.000000
# 1385    0.000000
# 1386    0.000000
# 1387    0.000000
# 1388    0.000000
# 1389    0.000000
# 1390    0.000000
# 1391    0.000000
# ...

# %%
ReplaceMissing(df,'droughts_floods_extreme_temps',0)
